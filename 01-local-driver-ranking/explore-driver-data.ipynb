# %%
# !pip install feast==0.29.0
# Out:
# Collecting feast==0.29.0
#   Downloading feast-0.29.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.8/29.8 MB 30.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: protobuf<5,>3 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (3.19.6)
# Requirement already satisfied: tqdm<5,>=4 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (4.64.1)
# Requirement already satisfied: PyYAML<7,>=5.4.0 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (5.4.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (1.56.4)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (3.2.0)
# Collecting pandavro~=1.5.0
#   Downloading pandavro-1.5.2.tar.gz (3.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting grpcio-reflection<2,>=1.47.0
#   Downloading grpcio_reflection-1.51.1-py3-none-any.whl (11 kB)
# Collecting httpx>=0.23.3
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 17.4 MB/s eta 0:00:00
# Collecting proto-plus<2,>=1.20.0
#   Downloading proto_plus-1.22.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 9.9 MB/s eta 0:00:00
# Collecting typeguard
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting toml<1,>=0.10.0
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting grpcio<2,>=1.47.0
#   Downloading grpcio-1.51.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 53.7 MB/s eta 0:00:00:00:01
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (7.1.2)
# Requirement already satisfied: dill~=0.3.0 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (0.3.4)
# Collecting fastapi<1,>=0.68.0
#   Downloading fastapi-0.92.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 13.2 MB/s eta 0:00:00
# Collecting pandas<2,>=1.4.3
#   Downloading pandas-1.5.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 48.2 MB/s eta 0:00:0000:0100:01
# Collecting uvicorn[standard]<1,>=0.14.0
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 13.0 MB/s eta 0:00:00
# Collecting dask>=2021.1.0
#   Downloading dask-2023.2.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 95.0 MB/s eta 0:00:00
# Collecting pyarrow<9,>=4
#   Downloading pyarrow-8.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 28.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: google-api-core<3,>=1.23.0 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (2.10.2)
# Requirement already satisfied: pygments<3,>=2.12.0 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (2.13.0)
# Collecting fastavro<2,>=1.1.0
#   Downloading fastavro-1.7.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 97.8 MB/s eta 0:00:00
# Collecting pydantic<2,>=1
#   Downloading pydantic-1.10.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 101.0 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2<4,>=2 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (3.1.2)
# Collecting numpy<3,>=1.22
#   Downloading numpy-1.24.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 43.5 MB/s eta 0:00:0000:0100:01
# Collecting bowler
#   Downloading bowler-0.9.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: tabulate<1,>=0.8.0 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (0.9.0)
# Collecting SQLAlchemy[mypy]<2,>1
#   Downloading SQLAlchemy-1.4.46-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 90.0 MB/s eta 0:00:00
# Collecting mmh3
#   Downloading mmh3-3.0.0-cp38-cp38-manylinux2010_x86_64.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: colorama<1,>=0.3.9 in /opt/conda/lib/python3.8/site-packages (from feast==0.29.0) (0.4.5)
# Collecting tenacity<9,>=7
#   Downloading tenacity-8.2.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from dask>=2021.1.0->feast==0.29.0) (21.3)
# Collecting partd>=0.3.10
#   Downloading partd-1.3.0-py3-none-any.whl (18 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2023.1.0-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 24.8 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.1.1 in /opt/conda/lib/python3.8/site-packages (from dask>=2021.1.0->feast==0.29.0) (1.6.0)
# Collecting toolz>=0.8.2
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 13.7 MB/s eta 0:00:00
# Collecting starlette<0.26.0,>=0.25.0
#   Downloading starlette-0.25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 1.4 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/conda/lib/python3.8/site-packages (from google-api-core<3,>=1.23.0->feast==0.29.0) (1.35.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.8/site-packages (from google-api-core<3,>=1.23.0->feast==0.29.0) (2.28.1)
# Collecting protobuf<5,>3
#   Downloading protobuf-4.22.0-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 47.8 MB/s eta 0:00:00
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /opt/conda/lib/python3.8/site-packages (from httpx>=0.23.3->feast==0.29.0) (2022.9.24)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.8/site-packages (from httpx>=0.23.3->feast==0.29.0) (1.3.0)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from Jinja2<4,>=2->feast==0.29.0) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.8/site-packages (from pandas<2,>=1.4.3->feast==0.29.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.8/site-packages (from pandas<2,>=1.4.3->feast==0.29.0) (2022.4)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.8/site-packages (from pandavro~=1.5.0->feast==0.29.0) (1.15.0)
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (618 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.5/618.5 kB 71.5 MB/s eta 0:00:00
# Collecting mypy>=0.910
#   Downloading mypy-1.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 40.9 MB/s eta 0:00:0000:0100:01
# Collecting sqlalchemy2-stubs
#   Downloading sqlalchemy2_stubs-0.0.2a32-py3-none-any.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.6/191.6 kB 36.3 MB/s eta 0:00:00
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.1 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-0.21.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.17.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 71.7 MB/s eta 0:00:00a 0:00:01
# Collecting httptools>=0.5.0
#   Downloading httptools-0.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 52.3 MB/s eta 0:00:00
# Collecting websockets>=10.4
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 16.8 MB/s eta 0:00:00
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.18.1-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs in /opt/conda/lib/python3.8/site-packages (from bowler->feast==0.29.0) (22.1.0)
# Collecting moreorless>=0.2.0
#   Downloading moreorless-0.4.0-py2.py3-none-any.whl (9.3 kB)
# Collecting volatile
#   Downloading volatile-2.1.0.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fissix
#   Downloading fissix-21.11.13-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 kB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema->feast==0.29.0) (0.18.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from jsonschema->feast==0.29.0) (65.4.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3,>=1.23.0->feast==0.29.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3,>=1.23.0->feast==0.29.0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3,>=1.23.0->feast==0.29.0) (0.2.8)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/conda/lib/python3.8/site-packages (from httpcore<0.17.0,>=0.15.0->httpx>=0.23.3->feast==0.29.0) (3.6.1)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->dask>=2021.1.0->feast==0.29.0) (3.0.9)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3,>=1.23.0->feast==0.29.0) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3,>=1.23.0->feast==0.29.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3,>=1.23.0->feast==0.29.0) (2.1.1)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3,>=1.23.0->feast==0.29.0) (0.4.8)
# Building wheels for collected packages: pandavro, volatile
#   Building wheel for pandavro (setup.py) ... done
#   Created wheel for pandavro: filename=pandavro-1.5.2-py3-none-any.whl size=2939 sha256=0b75b627043ee5482c597a36463b20f9ab8f6899c879b5fafefda0f69c0aaffb
#   Stored in directory: /home/jovyan/.cache/pip/wheels/21/03/ef/f7f69842521378eb3fd932bd3e13341e0b2c1617c56abc4da5
#   Building wheel for volatile (setup.py) ... done
#   Created wheel for volatile: filename=volatile-2.1.0-py3-none-any.whl size=3451 sha256=bdd3fda477c3e163efdc402f5931f633c80fc245371195968e765f2bd4a216c8
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0c/ef/7a/2eaf3bbba895518a953834e4ffd572d30ccd98900a253baea5
# Successfully built pandavro volatile
# Installing collected packages: volatile, rfc3986, mmh3, appdirs, websockets, uvloop, typing-extensions, typeguard, toolz, tomli, toml, tenacity, python-dotenv, protobuf, numpy, mypy-extensions, moreorless, locket, httptools, h11, grpcio, greenlet, fsspec, fissix, fastavro, watchfiles, uvicorn, starlette, sqlalchemy2-stubs, SQLAlchemy, pydantic, pyarrow, proto-plus, partd, pandas, mypy, httpcore, grpcio-reflection, bowler, pandavro, httpx, fastapi, dask, feast
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.34.1
#     Uninstalling grpcio-1.34.1:
#       Successfully uninstalled grpcio-1.34.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.4
#     Uninstalling pandas-1.2.4:
#       Successfully uninstalled pandas-1.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.5.3 requires grpcio~=1.34.0, but you have grpcio 1.51.1 which is incompatible.
# tensorflow 2.5.3 requires numpy~=1.19.2, but you have numpy 1.24.2 which is incompatible.
# tensorflow 2.5.3 requires typing-extensions~=3.7.4, but you have typing-extensions 4.5.0 which is incompatible.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.22.0 which is incompatible.
# scipy 1.7.0 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.2 which is incompatible.
# kfp 1.6.3 requires protobuf<4,>=3.13.0, but you have protobuf 4.22.0 which is incompatible.
# kfp-pipeline-spec 0.1.16 requires protobuf<4,>=3.13.0, but you have protobuf 4.22.0 which is incompatible.
# Successfully installed SQLAlchemy-1.4.46 appdirs-1.4.4 bowler-0.9.0 dask-2023.2.0 fastapi-0.92.0 fastavro-1.7.1 feast-0.29.0 fissix-21.11.13 fsspec-2023.1.0 greenlet-2.0.2 grpcio-1.51.1 grpcio-reflection-1.51.1 h11-0.14.0 httpcore-0.16.3 httptools-0.5.0 httpx-0.23.3 locket-1.0.0 mmh3-3.0.0 moreorless-0.4.0 mypy-1.0.1 mypy-extensions-1.0.0 numpy-1.24.2 pandas-1.5.3 pandavro-1.5.2 partd-1.3.0 proto-plus-1.22.2 protobuf-4.22.0 pyarrow-8.0.0 pydantic-1.10.5 python-dotenv-0.21.1 rfc3986-1.5.0 sqlalchemy2-stubs-0.0.2a32 starlette-0.25.0 tenacity-8.2.1 toml-0.10.2 tomli-2.0.1 toolz-0.12.0 typeguard-2.13.3 typing-extensions-4.5.0 uvicorn-0.20.0 uvloop-0.17.0 volatile-2.1.0 watchfiles-0.18.1 websockets-10.4

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.8/site-packages (0.24.2)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.8/site-packages (from scikit-learn) (1.7.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.8/site-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.8/site-packages (from scikit-learn) (1.2.0)

# %%
# !feast version
# Out:
# Feast is an open source project that collects anonymized error reporting and usage statistics. To opt out or learn more see https://docs.feast.dev/reference/usage
# Feast SDK Version: "feast 0.29.0"

# %%
# !feast init driver_feast_project
# Out:
# Creating a new Feast repository in /home/jovyan/driver_feast_project.

# %%
# check key overall architecture of the feature store
# !ls /home/jovyan/driver_feast_project
# !ls /home/jovyan/driver_feast_project/feature_repo

# !echo "###################check feature_store.yaml###################"
# !cat /home/jovyan/driver_feast_project/feature_repo/feature_store.yaml
# Out:
# feature_repo  __init__.py  README.md
# data			feature_store.yaml  __pycache__
# example_driver_repo.py	__init__.py	    test_workflow.py
# ###################check feature_store.yaml###################
# project: driver_feast_project
# # By default, the registry is a file (but can be turned into a more scalable SQL-backed registry)
# registry: data/registry.db
# # The provider primarily specifies default offline / online stores & storing the registry in a given cloud
# provider: local
# online_store:
#     type: sqlite
#     path: data/online_store.db
# entity_key_serialization_version: 2

# %% [markdown]
# # Inspecting the raw data

# %%
import pandas as pd
pd.read_parquet("/home/jovyan/driver_feast_project/feature_repo/data/driver_stats.parquet")
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 0    2021-08-31 18:00:00+00:00       1005   0.362754  0.697629
# 1    2021-08-31 19:00:00+00:00       1005   0.790768  0.821253
# 2    2021-08-31 20:00:00+00:00       1005   0.416623  0.939601
# 3    2021-08-31 21:00:00+00:00       1005   0.108623  0.818718
# 4    2021-08-31 22:00:00+00:00       1005   0.244842  0.511777
# ...                        ...        ...        ...       ...
# 1802 2021-09-15 16:00:00+00:00       1001   0.681178  0.449826
# 1803 2021-09-15 17:00:00+00:00       1001   0.812357  0.840873
# 1804 2021-04-12 07:00:00+00:00       1001   0.701558  0.195824
# 1805 2021-09-08 06:00:00+00:00       1003   0.084715  0.615489
# 1806 2021-09-08 06:00:00+00:00       1003   0.084715  0.615489
#
#       avg_daily_trips                 created string_feature
# 0                  31 2021-09-15 18:01:55.403           test
# 1                 520 2021-09-15 18:01:55.403           test
# 2                 777 2021-09-15 18:01:55.403           test
# 3                 750 2021-09-15 18:01:55.403           test
# 4                 954 2021-09-15 18:01:55.403           test
# ...               ...                     ...            ...
# 1802              906 2021-09-15 18:01:55.403           test
# 1803              714 2021-09-15 18:01:55.403           test
# 1804              566 2021-09-15 18:01:55.403           test
# 1805              523 2021-09-15 18:01:55.403           test
# 1806              523 2021-09-15 18:01:55.403           test
#
# [1807 rows x 7 columns]

# %% [markdown]
# # Apply and deploy feature definitions

# %%
# !cd /home/jovyan/driver_feast_project/feature_repo && feast apply
# Out:
# /opt/conda/lib/python3.8/site-packages/feast/infra/offline_stores/file_source.py:161: FutureWarning: 'ParquetDataset.schema' attribute is deprecated as of pyarrow 5.0.0 and will be removed in a future version. Specify 'use_legacy_dataset=False' while constructing the ParquetDataset, and then use the '.schema' attribute instead (which will return an Arrow schema instead of a Parquet schema).
#   schema = ParquetDataset(path).schema.to_arrow_schema()
# Created entity driver
# Created feature view driver_hourly_stats
#
# Created sqlite table driver_feast_project_driver_hourly_stats

# %%
# check key overall architecture of the feature store
# !ls /home/jovyan/driver_feast_project
# !ls /home/jovyan/driver_feast_project/feature_repo
# !ls /home/jovyan/driver_feast_project/feature_repo/data
# Out:
# feature_repo  __init__.py  README.md
# data			feature_store.yaml  __pycache__
# example_driver_repo.py	__init__.py	    test_workflow.py
# driver_stats.parquet  online_store.db  registry.db

# %% [markdown]
# # Generating training data

# %%
import feast
from joblib import dump
import pandas as pd
from datetime import datetime
from sklearn.linear_model import LinearRegression

# Load driver order data, when orders give to entity_df, it shows 0 entries  
orders = pd.read_csv("driver_orders.csv", sep="\t")
orders["event_timestamp"] = pd.to_datetime(orders["event_timestamp"])
print(orders)

entity_df = pd.DataFrame.from_dict(
    {
        # entity's join key -> entity values
        "driver_id": [1001, 1002, 1003, 1001, 1002],
        # "event_timestamp" (reserved key) -> timestamps
        "event_timestamp": [
            datetime(2021, 4, 12, 10, 59, 42),
            datetime(2021, 4, 12, 8, 12, 10),
            datetime(2021, 4, 12, 16, 40, 26),
            datetime(2021, 4, 12, 4, 29, 28),
            datetime(2021, 4, 12, 15, 40, 26),
        ],
        # (optional) label name -> label values. Feast does not process these
        "trip_completed": [1, 0, 0, 1, 0],
    }
)

# entity_df = pd.DataFrame.from_dict(
#     {
#         # entity's join key -> entity values
#         "driver_id": [1001, 1002, 1003, 1001, 1002, 1003, 1001, 1002, 1003, 1004],
#         # "event_timestamp" (reserved key) -> timestamps
#         "event_timestamp": [
#             datetime(2021, 4, 16, 20, 29, 28),
#             datetime(2021, 4, 17, 4, 29, 28),
#             datetime(2021, 4, 17, 12, 29, 28),
#             datetime(2021, 4, 17, 20, 29, 28),
#             datetime(2021, 4, 18, 4, 29, 28),
#             datetime(2021, 4, 18, 12, 29, 28),
#             datetime(2021, 4, 18, 20, 29, 28),
#             datetime(2021, 4, 19, 4, 29, 28),
#             datetime(2021, 4, 19, 12, 29, 28),
#             datetime(2021, 4, 19, 20, 29, 28),
#         ],
#         "trip_completed": [1, 0, 0, 1, 0, 0, 1, 0, 0, 1],
#     }
# )

# Connect to your feature store provider
fs = feast.FeatureStore(repo_path="/home/jovyan/driver_feast_project/feature_repo")

# Retrieve training data from driver_orders.csv
training_df = fs.get_historical_features(
    # entity_df=orders,
    entity_df=entity_df,
    features=[
        "driver_hourly_stats:conv_rate",
        "driver_hourly_stats:acc_rate",
        "driver_hourly_stats:avg_daily_trips",
    ],
).to_df()

print("----- Feature schema -----\n")
print(training_df.info())

print()
print("----- Example features -----\n")
print(training_df.head())
# Out:
#             event_timestamp  driver_id  trip_completed
# 0 2021-04-16 20:29:28+00:00       1001               1
# 1 2021-04-17 04:29:28+00:00       1002               0
# 2 2021-04-17 12:29:28+00:00       1003               0
# 3 2021-04-17 20:29:28+00:00       1001               1
# 4 2021-04-18 04:29:28+00:00       1002               0
# 5 2021-04-18 12:29:28+00:00       1003               0
# 6 2021-04-18 20:29:28+00:00       1001               1
# 7 2021-04-19 04:29:28+00:00       1002               0
# 8 2021-04-19 12:29:28+00:00       1003               0
# 9 2021-04-19 20:29:28+00:00       1004               1
# ----- Feature schema -----
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   driver_id        4 non-null      int64
#  1   event_timestamp  4 non-null      datetime64[ns, UTC]
#  2   trip_completed   4 non-null      int64
#  3   conv_rate        4 non-null      float32
#  4   acc_rate         4 non-null      float32
#  5   avg_daily_trips  4 non-null      int32
# dtypes: datetime64[ns, UTC](1), float32(2), int32(1), int64(2)
# memory usage: 272.0 bytes
# None
#
# ----- Example features -----
#
#    driver_id           event_timestamp  trip_completed  conv_rate  acc_rate  \
# 0       1001 2021-04-12 10:59:42+00:00               1   0.701558  0.195824
# 1       1002 2021-04-12 08:12:10+00:00               0   0.775499  0.947109
# 2       1003 2021-04-12 16:40:26+00:00               0   0.186658  0.245490
# 3       1002 2021-04-12 15:40:26+00:00               0   0.775499  0.947109
#
#    avg_daily_trips
# 0              566
# 1              890
# 2              971
# 3              890

# %% [markdown]
# ## Train model

# %%
# Train model
target = "trip_completed"

reg = LinearRegression()
train_X = training_df[training_df.columns.drop(target).drop("event_timestamp")]
train_Y = training_df.loc[:, target]
reg.fit(train_X[sorted(train_X)], train_Y)

# Save model
dump(reg, "driver_model.bin")
# Out:
# ['driver_model.bin']
